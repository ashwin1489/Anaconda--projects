# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pandas
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Ashwin\anaconda3
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.7.15  |       haa95532_0         127 KB
#     certifi-2025.8.3           |  py313haa95532_0         160 KB
#     ------------------------------------------------------------
#                                            Total:         288 KB
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2025.2.25-haa95532_0 --> 2025.7.15-haa95532_0
#   certifi                         2025.7.14-py313haa95532_0 --> 2025.8.3-py313haa95532_0
#
#
#
# ...
# certifi-2025.8.3     | 160 KB    |            |   0%
#
# ...

# %%
import pandas as pd

# %%
pd.Series([40,50,60,70,80,90,100])
# Out:
# 0     40
# 1     50
# 2     60
# 3     70
# 4     80
# 5     90
# 6    100
# dtype: int64

# %%
a = pd.Series([40,50,60,70,80,90,100],index = ["ash","win","aksh","auy","ram","shyam","radha"])

# %%
a
# Out:
# ash       40
# win       50
# aksh      60
# auy       70
# ram       80
# shyam     90
# radha    100
# dtype: int64

# %%
pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pd.DataFrame(data)
#
# NameError: name 'data' is not defined

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}
# Out:
#   Cell In[12], line 2
#     "name": ['a':"Alice", "Bob", "Charlie"],
#                 ^
# SyntaxError: invalid syntax

# %%
pd.DataFrame(data)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore
